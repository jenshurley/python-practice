# %%
import pandas as pd
import glob

# %%
glob.glob("*csv")

# %%
df = pd.read_csv('GrammarandProductReviews.csv')

# %%
df.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
# ...

# %%
df.shape

# %%
df.columns

# %%
df = df.fillna('')

# %%
df.describe()
# Out:
#        reviews.rating
# count    71044.000000
# mean         4.385747
# std          1.067659
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000

# %%
df['brand'].unique().shape
# Out:
# (392,)

# %%
df['categories'].unique().shape
# Out:
# (581,)

# %%
df.shape
# Out:
# (71044, 25)

# %%
df[df['reviews.title'].str.match('awesome')].mean()
# Out:
# reviews.rating    4.863158
# dtype: float64

# %%
df[df['reviews.title'].mean]

# %%
df[ (df['reviews.rating'] > 3) & (df['reviews.title'].str.contains('awesome'))]
# Out:
#                          id                 brand  \
# 395    AV1l8zRZvKc47QAVhnAv                  Olay
# 473    AV1l8zRZvKc47QAVhnAv                  Olay
# 620    AV1l8zRZvKc47QAVhnAv                  Olay
# 848    AV1YGDqsGV-KLJ3adc-O                Windex
# 898    AV1YGDqsGV-KLJ3adc-O                Windex
# 1089   AV1YmBrdGV-KLJ3adewb               Pantene
# 1159   AV1YmDL9vKc47QAVgr7_                Aussie
# 1488   AVpe_N91LJeJML43z4jD            Way Basics
# 1676   AVpe31o71cnluZ0-YrSD          Warner Bros.
# 1765   AVpe31o71cnluZ0-YrSD          Warner Bros.
# 1788   AVpe31o71cnluZ0-YrSD          Warner Bros.
# 2351   AVpe41TqilAPnD_xQH3d                   FOX
# 3323   AVpe5JOgilAPnD_xQPfE            Sony Music
# 4491   AVpe9W4D1cnluZ0-avf0                Hoover
# 4671   AVpf0eb2LJeJML43EVSt         Sony Pictures
# 4904   AVpf0eb2LJeJML43EVSt         Sony Pictures
# 4976   AVpf0eb2LJeJML43EVSt         Sony Pictures
# 5024   AVpf0eb2LJeJML43EVSt         Sony Pictures
# ...

# %%
df.brand.value_counts()
# Out:
# Clorox                        10700
# Universal Home Video           6178
# Tide                           5384
# FOX                            4498
# Disney                         3692
# Olay                           3420
# Warner Home Video              3330
# L'Oreal Paris                  2683
# L'oreal Paris                  2288
# Sony Pictures                  2161
# Rubbermaid                     1939
# Warner Bros.                   1920
# Quilted Northern               1439
# Lionsgate                      1351
# Burt's Bees                     965
# Summit Entertainment            821
# Nexxus                          773
# Maybelline                      742
# Pantene                         655
# Foodsaver                       587
# Head & Shoulders                565
# Kiss                            562
# Aveeno                          442
# Lundberg                        426
# Lemi Shine                      423
# Just For Men                    416
# ...
